# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet.git  # clone repo
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.1+cu113 (Tesla T4)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# %cd /content/Yolov5_StrongSORT_OSNet

# extract 14 seconds worth of video frames of it
# !yes | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:14 -c copy out.avi
# Out:
# /content/Yolov5_StrongSORT_OSNet
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'test.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:00:14.79, start: 0.000000, bitrate: 1974 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1870 kb/s, 24 fps, 24 tbr, 90k tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 98 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Output #0, avi, to 'out.avi':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 1870 kb/s, 24 fps, 24 tbr, 48 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(und): Audio: aac (LC) ([255][0][0][0] / 0x00FF), 44100 Hz, stereo, fltp, 98 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  336 fps=0.0 q=-1.0 Lsize=    3430kB time=00:00:13.97 bitrate=2010.0kbits/s speed=1.38e+03x
# video:3222kB audio:168kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.184175%

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# %pip install pyyaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (6.0)

# %%
# !python track.py --yolo-weights /content/Yolov5_StrongSORT_OSNet/yolov5/yolov5m.pt --strong-sort-weights osnet_x0_25_msmt17.pt --iou-thres 0.8 --source test.avi --save-txt --save-vid
# Out:
# strong_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# track: yolo_weights=['/content/Yolov5_StrongSORT_OSNet/yolov5/yolov5m.pt'], strong_sort_weights=osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=test.avi, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.8, max_det=1000, device=, show_vid=False, save_txt=True, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# requirements: tb-nightly not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flake8 5.0.4 requires importlib-metadata<4.3,>=1.1.0; python_version < "3.8", but you have importlib-metadata 4.12.0 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.7/dist-packages (2.11.0a20220817)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (57.4.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.2.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.21.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (2.23.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.47.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (3.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tb-nightly) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tb-nightly) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tb-nightly) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tb-nightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tb-nightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tb-nightly) (1.3.1)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly) (4.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tb-nightly) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tb-nightly) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tb-nightly) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tb-nightly) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly) (3.2.0)
# Installing collected packages: importlib-metadata
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.2.0
#     Uninstalling importlib-metadata-4.2.0:
#       Successfully uninstalled importlib-metadata-4.2.0
# Successfully installed importlib-metadata-4.12.0
#
# requirements: flake8 not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.4.1 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flake8 in /usr/local/lib/python3.7/dist-packages (5.0.4)
# Requirement already satisfied: pyflakes<2.6.0,>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from flake8) (2.5.0)
# Collecting importlib-metadata<4.3,>=1.1.0
#   Using cached importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from flake8) (0.7.0)
# Requirement already satisfied: pycodestyle<2.10.0,>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from flake8) (2.9.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3,>=1.1.0->flake8) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<4.3,>=1.1.0->flake8) (3.8.1)
# Installing collected packages: importlib-metadata
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.12.0
#     Uninstalling importlib-metadata-4.12.0:
#       Successfully uninstalled importlib-metadata-4.12.0
# Successfully installed importlib-metadata-4.2.0
#
# requirements: 2 packages updated per /content/Yolov5_StrongSORT_OSNet/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-8-18 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients
# Downloading...
# From: https://drive.google.com/uc?id=1Kkx2zW89jq_NETu4u42CFZTMVD5Hwm6e
# To: /content/Yolov5_StrongSORT_OSNet/osnet_x0_25_msmt17.pt
# 100% 9.34M/9.34M [00:00<00:00, 28.5MB/s]
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# video 1/1 (1/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.023s), StrongSORT:(0.131s)
# video 1/1 (2/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (3/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (4/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (5/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (6/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (7/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (8/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.145s)
# video 1/1 (9/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.129s)
# video 1/1 (10/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (11/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (12/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.136s)
# video 1/1 (13/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (14/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (15/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.120s)
# video 1/1 (16/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.117s)
# video 1/1 (17/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.127s)
# video 1/1 (18/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (19/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (20/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (21/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (22/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.135s)
# video 1/1 (23/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (24/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (25/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (26/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (27/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (28/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (29/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (30/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.173s)
# video 1/1 (31/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (32/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.145s)
# video 1/1 (33/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (34/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (35/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.136s)
# video 1/1 (36/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (37/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (38/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (39/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.135s)
# video 1/1 (40/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (41/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.146s)
# video 1/1 (42/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (43/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.157s)
# video 1/1 (44/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (45/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (46/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (47/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (48/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (49/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (50/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.135s)
# video 1/1 (51/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (52/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.118s)
# video 1/1 (53/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.113s)
# video 1/1 (54/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (55/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.023s), StrongSORT:(0.148s)
# video 1/1 (56/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.148s)
# video 1/1 (57/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (58/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (59/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.148s)
# video 1/1 (60/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.142s)
# video 1/1 (61/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (62/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (63/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.168s)
# video 1/1 (64/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (65/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.162s)
# video 1/1 (66/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (67/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (68/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (69/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (70/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.175s)
# video 1/1 (71/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (72/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.174s)
# video 1/1 (73/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (74/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (75/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.179s)
# video 1/1 (76/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.174s)
# video 1/1 (77/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (78/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (79/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.167s)
# video 1/1 (80/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.145s)
# video 1/1 (81/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.138s)
# video 1/1 (82/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (83/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.125s)
# video 1/1 (84/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.116s)
# video 1/1 (85/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.129s)
# video 1/1 (86/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.122s)
# video 1/1 (87/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.141s)
# video 1/1 (88/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.138s)
# video 1/1 (89/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (90/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (91/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 4 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.106s)
# video 1/1 (92/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 4 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.107s)
# video 1/1 (93/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (94/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.135s)
# video 1/1 (95/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.141s)
# video 1/1 (96/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (97/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.122s)
# video 1/1 (98/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.125s)
# video 1/1 (99/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.138s)
# video 1/1 (100/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.148s)
# video 1/1 (101/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (102/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (103/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (104/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.168s)
# video 1/1 (105/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (106/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (107/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.161s)
# video 1/1 (108/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.193s)
# video 1/1 (109/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.146s)
# video 1/1 (110/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (111/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (112/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.184s)
# video 1/1 (113/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (114/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.156s)
# video 1/1 (115/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (116/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (117/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (118/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (119/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (120/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (121/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (122/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (123/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (124/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.157s)
# video 1/1 (125/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.165s)
# video 1/1 (126/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (127/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (128/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (129/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (130/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 3 trucks, Done. YOLO:(0.023s), StrongSORT:(0.169s)
# video 1/1 (131/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (132/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (133/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (134/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (135/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.178s)
# video 1/1 (136/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (137/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.206s)
# video 1/1 (138/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.185s)
# video 1/1 (139/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 2 trucks, Done. YOLO:(0.023s), StrongSORT:(0.202s)
# video 1/1 (140/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.186s)
# video 1/1 (141/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.191s)
# video 1/1 (142/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.184s)
# video 1/1 (143/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.181s)
# video 1/1 (144/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.191s)
# video 1/1 (145/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (146/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.165s)
# video 1/1 (147/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.167s)
# video 1/1 (148/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (149/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 10 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.201s)
# video 1/1 (150/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.183s)
# video 1/1 (151/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (152/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.226s)
# video 1/1 (153/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 2 trucks, Done. YOLO:(0.023s), StrongSORT:(0.202s)
# video 1/1 (154/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (155/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.162s)
# video 1/1 (156/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (157/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (158/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (159/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (160/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (161/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.165s)
# video 1/1 (162/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.168s)
# video 1/1 (163/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (164/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.136s)
# video 1/1 (165/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.121s)
# video 1/1 (166/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.115s)
# video 1/1 (167/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.127s)
# video 1/1 (168/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.226s)
# video 1/1 (169/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.167s)
# video 1/1 (170/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.136s)
# video 1/1 (171/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.129s)
# video 1/1 (172/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.231s)
# video 1/1 (173/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (174/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (175/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (176/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (177/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (178/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (179/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (180/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.160s)
# video 1/1 (181/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (182/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.136s)
# video 1/1 (183/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (184/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (185/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.185s)
# video 1/1 (186/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.178s)
# video 1/1 (187/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.183s)
# video 1/1 (188/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.184s)
# video 1/1 (189/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.204s)
# video 1/1 (190/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.176s)
# video 1/1 (191/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.159s)
# video 1/1 (192/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 3 trucks, Done. YOLO:(0.022s), StrongSORT:(0.204s)
# video 1/1 (193/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.146s)
# video 1/1 (194/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.159s)
# video 1/1 (195/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.147s)
# video 1/1 (196/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.135s)
# video 1/1 (197/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (198/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (199/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (200/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (201/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (202/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.138s)
# video 1/1 (203/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (204/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.142s)
# video 1/1 (205/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.120s)
# video 1/1 (206/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.128s)
# video 1/1 (207/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (208/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (209/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.119s)
# video 1/1 (210/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.126s)
# video 1/1 (211/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.141s)
# video 1/1 (212/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.142s)
# video 1/1 (213/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.105s)
# video 1/1 (214/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.120s)
# video 1/1 (215/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.121s)
# video 1/1 (216/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.126s)
# video 1/1 (217/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.122s)
# video 1/1 (218/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (219/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.145s)
# video 1/1 (220/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.119s)
# video 1/1 (221/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.120s)
# video 1/1 (222/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.118s)
# video 1/1 (223/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.119s)
# video 1/1 (224/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.126s)
# video 1/1 (225/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (226/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (227/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (228/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (229/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (230/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.142s)
# video 1/1 (231/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 buss, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (232/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 buss, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (233/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (234/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.175s)
# video 1/1 (235/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.204s)
# video 1/1 (236/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.201s)
# video 1/1 (237/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.173s)
# video 1/1 (238/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.167s)
# video 1/1 (239/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (240/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (241/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.171s)
# video 1/1 (242/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (243/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.146s)
# video 1/1 (244/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.177s)
# video 1/1 (245/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.185s)
# video 1/1 (246/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (247/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (248/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (249/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (250/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.186s)
# video 1/1 (251/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.183s)
# video 1/1 (252/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (253/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (254/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (255/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.149s)
# video 1/1 (256/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (257/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (258/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.158s)
# video 1/1 (259/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (260/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (261/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (262/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (263/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.148s)
# video 1/1 (264/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (265/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.123s)
# video 1/1 (266/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.119s)
# video 1/1 (267/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (268/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 3 buss, Done. YOLO:(0.022s), StrongSORT:(0.158s)
# video 1/1 (269/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.133s)
# video 1/1 (270/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 3 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (271/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (272/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.158s)
# video 1/1 (273/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (274/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.154s)
# video 1/1 (275/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (276/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.182s)
# video 1/1 (277/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.185s)
# video 1/1 (278/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.168s)
# video 1/1 (279/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (280/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.145s)
# video 1/1 (281/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.156s)
# video 1/1 (282/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (283/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.171s)
# video 1/1 (284/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (285/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (286/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.188s)
# video 1/1 (287/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.186s)
# video 1/1 (288/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.188s)
# video 1/1 (289/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (290/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (291/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.203s)
# video 1/1 (292/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.198s)
# video 1/1 (293/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (294/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.181s)
# video 1/1 (295/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.186s)
# video 1/1 (296/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.206s)
# video 1/1 (297/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (298/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (299/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.153s)
# video 1/1 (300/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.160s)
# video 1/1 (301/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (302/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (303/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (304/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (305/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.161s)
# video 1/1 (306/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.155s)
# video 1/1 (307/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.159s)
# video 1/1 (308/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.139s)
# video 1/1 (309/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 5 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.116s)
# video 1/1 (310/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (311/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.142s)
# video 1/1 (312/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 2 buss, Done. YOLO:(0.022s), StrongSORT:(0.144s)
# video 1/1 (313/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (314/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.122s)
# video 1/1 (315/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.151s)
# video 1/1 (316/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 6 cars, 1 bus, 2 trucks, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (317/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.162s)
# video 1/1 (318/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.134s)
# video 1/1 (319/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.137s)
# video 1/1 (320/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.132s)
# video 1/1 (321/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.163s)
# video 1/1 (322/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.173s)
# video 1/1 (323/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.162s)
# video 1/1 (324/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.180s)
# video 1/1 (325/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.159s)
# video 1/1 (326/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.150s)
# video 1/1 (327/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.159s)
# video 1/1 (328/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.172s)
# video 1/1 (329/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 10 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.182s)
# video 1/1 (330/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (331/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (332/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.176s)
# video 1/1 (333/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (334/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (335/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (336/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (337/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.157s)
# video 1/1 (338/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.130s)
# video 1/1 (339/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.131s)
# video 1/1 (340/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.141s)
# video 1/1 (341/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.164s)
# video 1/1 (342/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (343/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.140s)
# video 1/1 (344/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.141s)
# video 1/1 (345/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, Done. YOLO:(0.022s), StrongSORT:(0.143s)
# video 1/1 (346/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.166s)
# video 1/1 (347/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.160s)
# video 1/1 (348/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.170s)
# video 1/1 (349/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.178s)
# video 1/1 (350/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 7 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.152s)
# video 1/1 (351/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.162s)
# video 1/1 (352/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 8 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.169s)
# video 1/1 (353/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.182s)
# video 1/1 (354/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.178s)
# video 1/1 (355/355) /content/Yolov5_StrongSORT_OSNet/test.avi: 384x640 9 cars, 1 bus, 1 truck, Done. YOLO:(0.022s), StrongSORT:(0.184s)
# Speed: 0.4ms pre-process, 22.4ms inference, 1.1ms NMS, 152.4ms strong sort update per image at shape (1, 3, 640, 640)
# Results saved to runs/track/exp2
# 1 tracks saved to runs/track/exp2/tracks

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i /content/Yolov5_StrongSORT_OSNet/runs/track/exp2/test.mp4 output.mp4 -y
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/Yolov5_StrongSORT_OSNet/runs/track/exp2/test.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:14.79, start: 0.000000, bitrate: 4251 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 4250 kb/s, 24 fps, 24 tbr, 12288 tbn, 24 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55797437b900] using SAR=1/1
# [libx264 @ 0x55797437b900] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55797437b900] profile High, level 3.1
# [libx264 @ 0x55797437b900] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 24 fps, 12288 tbn, 24 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  355 fps= 24 q=-1.0 Lsize=    2607kB time=00:00:14.66 bitrate=1456.3kbits/s speed=0.982x
# video:2602kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.185109%
# [libx264 @ 0x55797437b900] frame I:2     Avg QP:19.07  size: 67098
# [libx264 @ 0x55797437b900] frame P:125   Avg QP:21.14  size: 14768
# [libx264 @ 0x55797437b900] frame B:228   Avg QP:26.87  size:  3000
# [libx264 @ 0x55797437b900] consecutive B-frames:  8.2% 13.0% 16.9% 62.0%
# [libx264 @ 0x55797437b900] mb I  I16..4: 13.1% 76.7% 10.2%
# [libx264 @ 0x55797437b900] mb P  I16..4:  0.9%  5.6%  0.8%  P16..4: 30.4% 11.8%  7.7%  0.0%  0.0%    skip:42.7%
# [libx264 @ 0x55797437b900] mb B  I16..4:  0.1%  0.4%  0.1%  B16..8: 26.8%  2.5%  0.5%  direct: 0.5%  skip:69.1%  L0:48.8% L1:48.2% BI: 3.1%
# [libx264 @ 0x55797437b900] 8x8 transform intra:75.2% inter:74.5%
# [libx264 @ 0x55797437b900] coded y,uvDC,uvAC intra: 64.6% 66.0% 17.6% inter: 7.7% 10.4% 3.0%
# [libx264 @ 0x55797437b900] i16 v,h,dc,p: 38% 31% 26%  6%
# [libx264 @ 0x55797437b900] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 24% 34%  3%  2%  3%  2%  3%  4%
# [libx264 @ 0x55797437b900] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 36% 12%  4%  4%  5%  5%  4%  4%
# [libx264 @ 0x55797437b900] i8c dc,h,v,p: 41% 28% 27%  3%
# [libx264 @ 0x55797437b900] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55797437b900] ref P L0: 68.3% 10.1% 15.8%  5.8%
# [libx264 @ 0x55797437b900] ref B L0: 81.6% 15.4%  2.9%
# [libx264 @ 0x55797437b900] ref B L1: 95.5%  4.5%
# [libx264 @ 0x55797437b900] kb/s:1440.94

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
from glob import glob

out_path = glob('/content/Yolov5_StrongSORT_OSNet/runs/track/exp2/tracks/*.txt')
out_path
# Out:
# ['/content/Yolov5_StrongSORT_OSNet/runs/track/exp2/tracks/test.txt']

# %%
########## 객체 id, 좌표 값 저장한 txt 파일 List로 변형하는 함수 ##########

def Text_List(out_path):
  result = [] # 최종적으로 받을 리스트
  for op in out_path:
    with open(op, 'r') as f: # close 없이 txt 파일 읽어와서 f에 적용
      example = f.readlines() # ['첫 번째 줄 \n', '두 번째 줄 \n', '세 번째 줄'] 식으로 저장
      # print(example)
      temp, now_fps, idx = [[]], example[0].split(' ')[0], 0
      # temp => fps(프레임) 별로 받기 위한 2중 리스트
      # now_fps => 가장 첫 번째 프레임 (이전 프레임)
      # idx => temp의 프레임 별 index
      for ex in example:
        if now_fps != ex.split(' ')[0]: # 이전 프레임과 현재 프레임이 다르면 = 다음 프레임으로 넘어가면
          temp.append([]) # temp에 다음 프레임의 빈 리스트를 만들어줌
          idx += 1
          now_fps = ex.split(' ')[0] # 이전 프레임을 현재 프레임으로 업데이트
        temp[idx].append(list(int(x) for x in ex.split(' ')[1:-5])) # txt 파일에서 [id, x, y ,width, height]만 뽑아서 저장
      result.append(temp)
  return result

# %%
import numpy as np

just_do = Text_List(out_path)
print(np.shape(just_do), '\n')
for x in just_do:
  print('\n', np.shape(x), '\n')
  for y in x:
    print(np.shape(y))
# Out:
# (1, 353)
#
#
#  (353,)
#
# (16, 5)
# (16, 5)
# (15, 5)
# (18, 5)
# (17, 5)
# (15, 5)
# (15, 5)
# (16, 5)
# (16, 5)
# (16, 5)
# (16, 5)
# (16, 5)
# (15, 5)
# (15, 5)
# (15, 5)
# (14, 5)
# (15, 5)
# (16, 5)
# (15, 5)
# (16, 5)
# (17, 5)
# (17, 5)
# (16, 5)
# (16, 5)
# (16, 5)
# (17, 5)
# (16, 5)
# (15, 5)
# (13, 5)
# (16, 5)
# (18, 5)
# (17, 5)
# (16, 5)
# (15, 5)
# (15, 5)
# (14, 5)
# (15, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (16, 5)
# (16, 5)
# (17, 5)
# (16, 5)
# (16, 5)
# (17, 5)
# (17, 5)
# (16, 5)
# (17, 5)
# (14, 5)
# (14, 5)
# (16, 5)
# (15, 5)
# (15, 5)
# (15, 5)
# (16, 5)
# (17, 5)
# (17, 5)
# (17, 5)
# (17, 5)
# (17, 5)
# (13, 5)
# (15, 5)
# (15, 5)
# (14, 5)
# (15, 5)
# (15, 5)
# (14, 5)
# (11, 5)
# (12, 5)
# (13, 5)
# (12, 5)
# (13, 5)
# (13, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (11, 5)
# (12, 5)
# (11, 5)
# (12, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (11, 5)
# (10, 5)
# (10, 5)
# (9, 5)
# (9, 5)
# (11, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (13, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (11, 5)
# (12, 5)
# (10, 5)
# (15, 5)
# (14, 5)
# (11, 5)
# (12, 5)
# (11, 5)
# (14, 5)
# (13, 5)
# (13, 5)
# (11, 5)
# (10, 5)
# (13, 5)
# (13, 5)
# (12, 5)
# (13, 5)
# (15, 5)
# (13, 5)
# (13, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (13, 5)
# (14, 5)
# (14, 5)
# (13, 5)
# (13, 5)
# (13, 5)
# (15, 5)
# (13, 5)
# (13, 5)
# (13, 5)
# (12, 5)
# (14, 5)
# (16, 5)
# (15, 5)
# (14, 5)
# (14, 5)
# (12, 5)
# (12, 5)
# (12, 5)
# (13, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (13, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (13, 5)
# (10, 5)
# (12, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (14, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (12, 5)
# (11, 5)
# (13, 5)
# (12, 5)
# (12, 5)
# (12, 5)
# (12, 5)
# (13, 5)
# (15, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (12, 5)
# (15, 5)
# (13, 5)
# (14, 5)
# (16, 5)
# (15, 5)
# (6, 5)
# (15, 5)
# (14, 5)
# (11, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (12, 5)
# (12, 5)
# (13, 5)
# (12, 5)
# (14, 5)
# (15, 5)
# (16, 5)
# (13, 5)
# (12, 5)
# (12, 5)
# (10, 5)
# (11, 5)
# (11, 5)
# (9, 5)
# (11, 5)
# (11, 5)
# (14, 5)
# (9, 5)
# (11, 5)
# (11, 5)
# (13, 5)
# (12, 5)
# (12, 5)
# (10, 5)
# (12, 5)
# (12, 5)
# (9, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (12, 5)
# (9, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (12, 5)
# (13, 5)
# (13, 5)
# (14, 5)
# (11, 5)
# (12, 5)
# (11, 5)
# (13, 5)
# (11, 5)
# (14, 5)
# (15, 5)
# (14, 5)
# (14, 5)
# (13, 5)
# (13, 5)
# (14, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (14, 5)
# (13, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (13, 5)
# (13, 5)
# (11, 5)
# (11, 5)
# (12, 5)
# (13, 5)
# (12, 5)
# (12, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (14, 5)
# (12, 5)
# (14, 5)
# (13, 5)
# (14, 5)
# (12, 5)
# (13, 5)
# (12, 5)
# (15, 5)
# (13, 5)
# (13, 5)
# (13, 5)
# (12, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (13, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (10, 5)
# (13, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (8, 5)
# (9, 5)
# (9, 5)
# (9, 5)
# (12, 5)
# (11, 5)
# (10, 5)
# (13, 5)
# (13, 5)
# (11, 5)
# (11, 5)
# (10, 5)
# (11, 5)
# (11, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (8, 5)
# (8, 5)
# (8, 5)
# (9, 5)
# (9, 5)
# (9, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (9, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (10, 5)
# (10, 5)
# (10, 5)
# (11, 5)
# (11, 5)
# (11, 5)
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape
